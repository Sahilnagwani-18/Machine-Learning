# %%
import numpy as np
import matplotlib.pyplot as plt
import os


os.makedirs("die_histograms", exist_ok=True)

roll_counts = range(1, 51)

experiments = [100, 500, 1000, 5000, 10000, 50000, 100000]

results = {}

for n_rolls in roll_counts:
    results[n_rolls] = {}
    for n_exp in experiments:
        
        rolls = np.random.randint(1, 7, size=(n_exp, n_rolls))
        sums = rolls.sum(axis=1)

       
        mean_val = np.mean(sums)
        var_val = np.var(sums)

        results[n_rolls][n_exp] = (mean_val, var_val)

        plt.figure(figsize=(8, 5))
        plt.hist(sums, bins=30, density=True, alpha=0.7, color='skyblue', edgecolor='black')
        plt.title(f"Histogram of {n_rolls} rolls, {n_exp} experiments\nMean={mean_val:.2f}, Var={var_val:.2f}")
        plt.xlabel("Sum of dice rolls")
        plt.ylabel("Probability Density")
        plt.grid(alpha=0.3)

        
        plt.savefig(f"die_histograms/hist_{n_rolls}rolls_{n_exp}exp.png")
        plt.close()


for n_rolls in results:
    print(f"\n--- {n_rolls} Rolls ---")
    for n_exp, (mean_val, var_val) in results[n_rolls].items():
        print(f"Experiments={n_exp}: Mean={mean_val:.2f}, Variance={var_val:.2f}")
# Out:
# --- 1 Rolls ---
# Experiments=100: Mean=3.46, Variance=2.77
# Experiments=500: Mean=3.53, Variance=2.99
# Experiments=1000: Mean=3.52, Variance=2.85
# Experiments=5000: Mean=3.53, Variance=2.91
# Experiments=10000: Mean=3.49, Variance=2.89
# Experiments=50000: Mean=3.50, Variance=2.91
# Experiments=100000: Mean=3.50, Variance=2.92
#
# --- 2 Rolls ---
# Experiments=100: Mean=6.85, Variance=5.85
# Experiments=500: Mean=6.98, Variance=5.65
# Experiments=1000: Mean=6.97, Variance=5.45
# Experiments=5000: Mean=7.02, Variance=5.88
# Experiments=10000: Mean=7.02, Variance=5.77
# Experiments=50000: Mean=6.99, Variance=5.78
# Experiments=100000: Mean=7.00, Variance=5.84
#
# --- 3 Rolls ---
# Experiments=100: Mean=10.55, Variance=8.29
# Experiments=500: Mean=10.50, Variance=8.59
# Experiments=1000: Mean=10.43, Variance=8.57
# Experiments=5000: Mean=10.47, Variance=8.66
# Experiments=10000: Mean=10.53, Variance=8.79
# Experiments=50000: Mean=10.52, Variance=8.82
# Experiments=100000: Mean=10.50, Variance=8.76
#
# --- 4 Rolls ---
# Experiments=100: Mean=13.89, Variance=13.32
# Experiments=500: Mean=13.70, Variance=12.40
# Experiments=1000: Mean=13.97, Variance=11.78
# Experiments=5000: Mean=13.91, Variance=11.57
# Experiments=10000: Mean=13.98, Variance=11.89
# Experiments=50000: Mean=13.99, Variance=11.75
# Experiments=100000: Mean=14.00, Variance=11.67
#
# --- 5 Rolls ---
# Experiments=100: Mean=17.87, Variance=13.21
# Experiments=500: Mean=17.48, Variance=14.96
# Experiments=1000: Mean=17.52, Variance=14.00
# Experiments=5000: Mean=17.53, Variance=14.32
# Experiments=10000: Mean=17.49, Variance=14.65
# Experiments=50000: Mean=17.50, Variance=14.58
# Experiments=100000: Mean=17.50, Variance=14.61
#
# --- 6 Rolls ---
# Experiments=100: Mean=20.90, Variance=15.73
# Experiments=500: Mean=21.19, Variance=18.30
# Experiments=1000: Mean=21.12, Variance=18.51
# Experiments=5000: Mean=21.03, Variance=17.08
# Experiments=10000: Mean=21.02, Variance=17.25
# Experiments=50000: Mean=21.00, Variance=17.66
# Experiments=100000: Mean=21.00, Variance=17.50
#
# --- 7 Rolls ---
# Experiments=100: Mean=24.10, Variance=19.49
# Experiments=500: Mean=24.48, Variance=20.71
# Experiments=1000: Mean=24.58, Variance=19.11
# Experiments=5000: Mean=24.55, Variance=20.32
# Experiments=10000: Mean=24.49, Variance=21.12
# Experiments=50000: Mean=24.49, Variance=20.38
# Experiments=100000: Mean=24.49, Variance=20.31
#
# --- 8 Rolls ---
# Experiments=100: Mean=28.42, Variance=25.56
# Experiments=500: Mean=28.06, Variance=24.90
# Experiments=1000: Mean=27.93, Variance=24.47
# Experiments=5000: Mean=27.98, Variance=24.27
# Experiments=10000: Mean=28.05, Variance=23.74
# Experiments=50000: Mean=27.99, Variance=23.46
# Experiments=100000: Mean=28.00, Variance=23.51
#
# --- 9 Rolls ---
# Experiments=100: Mean=31.24, Variance=23.12
# Experiments=500: Mean=31.58, Variance=26.07
# Experiments=1000: Mean=31.41, Variance=28.15
# Experiments=5000: Mean=31.47, Variance=26.74
# Experiments=10000: Mean=31.57, Variance=25.59
# Experiments=50000: Mean=31.51, Variance=26.33
# Experiments=100000: Mean=31.52, Variance=26.11
#
# --- 10 Rolls ---
# Experiments=100: Mean=34.65, Variance=27.89
# Experiments=500: Mean=34.71, Variance=29.77
# Experiments=1000: Mean=35.01, Variance=29.39
# Experiments=5000: Mean=35.02, Variance=29.50
# Experiments=10000: Mean=34.96, Variance=28.98
# Experiments=50000: Mean=35.03, Variance=29.07
# Experiments=100000: Mean=35.02, Variance=29.27
#
# --- 11 Rolls ---
# Experiments=100: Mean=37.86, Variance=40.34
# Experiments=500: Mean=38.64, Variance=32.56
# Experiments=1000: Mean=38.46, Variance=30.64
# Experiments=5000: Mean=38.49, Variance=32.38
# Experiments=10000: Mean=38.46, Variance=32.78
# Experiments=50000: Mean=38.52, Variance=31.87
# Experiments=100000: Mean=38.49, Variance=32.40
#
# --- 12 Rolls ---
# Experiments=100: Mean=41.03, Variance=28.57
# Experiments=500: Mean=42.23, Variance=31.87
# Experiments=1000: Mean=41.85, Variance=33.30
# Experiments=5000: Mean=41.91, Variance=34.37
# Experiments=10000: Mean=41.92, Variance=34.50
# Experiments=50000: Mean=42.01, Variance=34.81
# Experiments=100000: Mean=42.00, Variance=35.19
#
# --- 13 Rolls ---
# Experiments=100: Mean=45.44, Variance=39.35
# Experiments=500: Mean=45.40, Variance=32.10
# Experiments=1000: Mean=45.37, Variance=40.45
# Experiments=5000: Mean=45.40, Variance=37.86
# Experiments=10000: Mean=45.44, Variance=37.95
# Experiments=50000: Mean=45.50, Variance=37.83
# Experiments=100000: Mean=45.50, Variance=37.92
#
# --- 14 Rolls ---
# Experiments=100: Mean=49.13, Variance=38.77
# Experiments=500: Mean=48.53, Variance=40.93
# Experiments=1000: Mean=49.05, Variance=42.48
# Experiments=5000: Mean=48.91, Variance=41.07
# Experiments=10000: Mean=49.02, Variance=39.98
# Experiments=50000: Mean=49.01, Variance=41.11
# Experiments=100000: Mean=48.97, Variance=40.53
#
# --- 15 Rolls ---
# Experiments=100: Mean=53.41, Variance=44.82
# Experiments=500: Mean=52.21, Variance=37.97
# Experiments=1000: Mean=52.28, Variance=45.63
# Experiments=5000: Mean=52.40, Variance=44.56
# Experiments=10000: Mean=52.44, Variance=43.05
# Experiments=50000: Mean=52.47, Variance=44.12
# Experiments=100000: Mean=52.49, Variance=43.75
#
# --- 16 Rolls ---
# Experiments=100: Mean=56.72, Variance=51.76
# Experiments=500: Mean=56.05, Variance=45.16
# Experiments=1000: Mean=56.25, Variance=45.96
# Experiments=5000: Mean=55.92, Variance=47.57
# Experiments=10000: Mean=55.98, Variance=47.13
# Experiments=50000: Mean=55.97, Variance=46.20
# Experiments=100000: Mean=55.99, Variance=46.63
#
# --- 17 Rolls ---
# Experiments=100: Mean=59.22, Variance=50.37
# Experiments=500: Mean=59.67, Variance=52.38
# Experiments=1000: Mean=59.53, Variance=53.22
# Experiments=5000: Mean=59.57, Variance=49.64
# Experiments=10000: Mean=59.45, Variance=49.70
# Experiments=50000: Mean=59.50, Variance=49.72
# Experiments=100000: Mean=59.45, Variance=49.63
#
# --- 18 Rolls ---
# Experiments=100: Mean=62.88, Variance=53.23
# Experiments=500: Mean=62.92, Variance=54.86
# Experiments=1000: Mean=63.02, Variance=48.61
# Experiments=5000: Mean=63.09, Variance=52.35
# Experiments=10000: Mean=63.07, Variance=51.23
# Experiments=50000: Mean=62.97, Variance=53.03
# Experiments=100000: Mean=63.02, Variance=52.36
#
# --- 19 Rolls ---
# Experiments=100: Mean=66.09, Variance=59.26
# Experiments=500: Mean=66.53, Variance=50.27
# Experiments=1000: Mean=66.40, Variance=55.74
# Experiments=5000: Mean=66.58, Variance=54.98
# Experiments=10000: Mean=66.48, Variance=55.10
# Experiments=50000: Mean=66.51, Variance=55.96
# Experiments=100000: Mean=66.50, Variance=55.87
#
# --- 20 Rolls ---
# Experiments=100: Mean=70.36, Variance=62.17
# Experiments=500: Mean=70.29, Variance=60.02
# Experiments=1000: Mean=70.25, Variance=54.54
# Experiments=5000: Mean=70.15, Variance=60.09
# Experiments=10000: Mean=70.04, Variance=59.68
# Experiments=50000: Mean=69.93, Variance=58.17
# Experiments=100000: Mean=70.03, Variance=58.17
#
# --- 21 Rolls ---
# Experiments=100: Mean=73.32, Variance=66.82
# Experiments=500: Mean=74.05, Variance=60.69
# Experiments=1000: Mean=73.42, Variance=62.98
# Experiments=5000: Mean=73.58, Variance=60.02
# Experiments=10000: Mean=73.47, Variance=60.37
# Experiments=50000: Mean=73.51, Variance=61.73
# Experiments=100000: Mean=73.55, Variance=61.11
#
# --- 22 Rolls ---
# Experiments=100: Mean=77.98, Variance=69.04
# Experiments=500: Mean=77.07, Variance=63.58
# Experiments=1000: Mean=77.20, Variance=63.96
# Experiments=5000: Mean=76.93, Variance=64.09
# Experiments=10000: Mean=77.12, Variance=62.86
# Experiments=50000: Mean=77.05, Variance=64.10
# Experiments=100000: Mean=77.03, Variance=63.65
#
# --- 23 Rolls ---
# Experiments=100: Mean=80.65, Variance=55.95
# Experiments=500: Mean=80.37, Variance=69.36
# Experiments=1000: Mean=80.66, Variance=69.70
# Experiments=5000: Mean=80.40, Variance=67.09
# Experiments=10000: Mean=80.53, Variance=66.97
# Experiments=50000: Mean=80.46, Variance=67.60
# Experiments=100000: Mean=80.50, Variance=67.00
#
# --- 24 Rolls ---
# Experiments=100: Mean=84.94, Variance=73.46
# Experiments=500: Mean=83.97, Variance=72.27
# Experiments=1000: Mean=83.52, Variance=63.95
# Experiments=5000: Mean=84.02, Variance=70.03
# Experiments=10000: Mean=83.91, Variance=69.64
# Experiments=50000: Mean=84.06, Variance=69.64
# Experiments=100000: Mean=84.00, Variance=69.75
#
# --- 25 Rolls ---
# Experiments=100: Mean=87.10, Variance=61.35
# Experiments=500: Mean=87.75, Variance=73.15
# Experiments=1000: Mean=87.13, Variance=70.82
# Experiments=5000: Mean=87.41, Variance=71.57
# Experiments=10000: Mean=87.54, Variance=74.25
# Experiments=50000: Mean=87.43, Variance=72.84
# Experiments=100000: Mean=87.46, Variance=72.95
#
# --- 26 Rolls ---
# Experiments=100: Mean=92.33, Variance=61.80
# Experiments=500: Mean=91.36, Variance=80.23
# Experiments=1000: Mean=91.08, Variance=76.95
# Experiments=5000: Mean=90.89, Variance=78.34
# Experiments=10000: Mean=91.07, Variance=75.04
# Experiments=50000: Mean=90.99, Variance=75.47
# Experiments=100000: Mean=91.02, Variance=76.32
#
# --- 27 Rolls ---
# Experiments=100: Mean=94.50, Variance=95.95
# Experiments=500: Mean=94.74, Variance=81.40
# Experiments=1000: Mean=94.51, Variance=84.96
# Experiments=5000: Mean=94.67, Variance=80.13
# Experiments=10000: Mean=94.57, Variance=79.32
# Experiments=50000: Mean=94.51, Variance=78.74
# Experiments=100000: Mean=94.48, Variance=78.99
#
# --- 28 Rolls ---
# Experiments=100: Mean=98.54, Variance=80.19
# Experiments=500: Mean=97.76, Variance=82.31
# Experiments=1000: Mean=97.74, Variance=76.11
# Experiments=5000: Mean=97.86, Variance=82.26
# Experiments=10000: Mean=97.95, Variance=81.25
# Experiments=50000: Mean=97.95, Variance=81.99
# Experiments=100000: Mean=98.02, Variance=81.66
#
# --- 29 Rolls ---
# Experiments=100: Mean=102.40, Variance=68.88
# Experiments=500: Mean=101.12, Variance=82.81
# Experiments=1000: Mean=101.14, Variance=88.57
# Experiments=5000: Mean=101.44, Variance=86.49
# Experiments=10000: Mean=101.54, Variance=85.38
# Experiments=50000: Mean=101.45, Variance=85.93
# Experiments=100000: Mean=101.54, Variance=84.86
#
# --- 30 Rolls ---
# Experiments=100: Mean=104.53, Variance=72.27
# Experiments=500: Mean=105.38, Variance=81.13
# Experiments=1000: Mean=105.11, Variance=84.83
# Experiments=5000: Mean=104.97, Variance=85.42
# Experiments=10000: Mean=105.10, Variance=88.76
# Experiments=50000: Mean=104.99, Variance=87.92
# Experiments=100000: Mean=105.04, Variance=87.28
#
# --- 31 Rolls ---
# Experiments=100: Mean=108.49, Variance=95.07
# Experiments=500: Mean=108.80, Variance=92.79
# Experiments=1000: Mean=108.57, Variance=93.60
# Experiments=5000: Mean=108.46, Variance=95.18
# Experiments=10000: Mean=108.47, Variance=90.85
# Experiments=50000: Mean=108.51, Variance=90.08
# Experiments=100000: Mean=108.50, Variance=90.30
#
# --- 32 Rolls ---
# Experiments=100: Mean=112.48, Variance=95.57
# Experiments=500: Mean=111.25, Variance=91.08
# Experiments=1000: Mean=112.32, Variance=92.44
# Experiments=5000: Mean=112.02, Variance=89.16
# Experiments=10000: Mean=112.02, Variance=92.82
# Experiments=50000: Mean=112.01, Variance=92.95
# Experiments=100000: Mean=112.00, Variance=93.05
#
# --- 33 Rolls ---
# Experiments=100: Mean=115.05, Variance=103.55
# Experiments=500: Mean=115.85, Variance=87.96
# Experiments=1000: Mean=115.53, Variance=105.23
# Experiments=5000: Mean=115.45, Variance=96.54
# Experiments=10000: Mean=115.57, Variance=96.84
# Experiments=50000: Mean=115.47, Variance=96.49
# Experiments=100000: Mean=115.52, Variance=95.89
#
# --- 34 Rolls ---
# Experiments=100: Mean=118.77, Variance=101.64
# Experiments=500: Mean=119.08, Variance=99.28
# Experiments=1000: Mean=119.18, Variance=98.62
# Experiments=5000: Mean=119.12, Variance=102.37
# Experiments=10000: Mean=119.01, Variance=95.42
# Experiments=50000: Mean=119.05, Variance=98.94
# Experiments=100000: Mean=118.98, Variance=99.43
#
# --- 35 Rolls ---
# Experiments=100: Mean=121.89, Variance=114.38
# Experiments=500: Mean=122.09, Variance=100.97
# Experiments=1000: Mean=122.83, Variance=103.08
# Experiments=5000: Mean=122.59, Variance=98.97
# Experiments=10000: Mean=122.52, Variance=103.60
# Experiments=50000: Mean=122.50, Variance=101.63
# Experiments=100000: Mean=122.49, Variance=102.82
#
# --- 36 Rolls ---
# Experiments=100: Mean=125.44, Variance=126.73
# Experiments=500: Mean=126.29, Variance=106.94
# Experiments=1000: Mean=125.71, Variance=100.99
# Experiments=5000: Mean=125.83, Variance=105.66
# Experiments=10000: Mean=125.90, Variance=105.42
# Experiments=50000: Mean=126.09, Variance=105.76
# Experiments=100000: Mean=126.01, Variance=104.48
#
# --- 37 Rolls ---
# Experiments=100: Mean=129.19, Variance=71.43
# Experiments=500: Mean=128.81, Variance=114.34
# Experiments=1000: Mean=130.09, Variance=103.76
# Experiments=5000: Mean=129.15, Variance=106.44
# Experiments=10000: Mean=129.52, Variance=110.80
# Experiments=50000: Mean=129.47, Variance=106.72
# Experiments=100000: Mean=129.50, Variance=108.25
#
# --- 38 Rolls ---
# Experiments=100: Mean=133.05, Variance=98.75
# Experiments=500: Mean=133.50, Variance=112.67
# Experiments=1000: Mean=132.64, Variance=106.17
# Experiments=5000: Mean=133.18, Variance=112.74
# Experiments=10000: Mean=133.11, Variance=108.91
# Experiments=50000: Mean=133.05, Variance=110.45
# Experiments=100000: Mean=132.96, Variance=110.29
#
# --- 39 Rolls ---
# Experiments=100: Mean=135.45, Variance=144.35
# Experiments=500: Mean=137.22, Variance=120.43
# Experiments=1000: Mean=136.01, Variance=113.17
# Experiments=5000: Mean=136.39, Variance=114.29
# Experiments=10000: Mean=136.48, Variance=112.44
# Experiments=50000: Mean=136.58, Variance=113.03
# Experiments=100000: Mean=136.50, Variance=114.01
#
# --- 40 Rolls ---
# Experiments=100: Mean=139.96, Variance=110.70
# Experiments=500: Mean=140.00, Variance=121.59
# Experiments=1000: Mean=139.45, Variance=116.07
# Experiments=5000: Mean=139.71, Variance=116.72
# Experiments=10000: Mean=139.89, Variance=119.09
# Experiments=50000: Mean=140.01, Variance=116.63
# Experiments=100000: Mean=140.01, Variance=116.56
#
# --- 41 Rolls ---
# Experiments=100: Mean=142.16, Variance=129.61
# Experiments=500: Mean=143.76, Variance=113.74
# Experiments=1000: Mean=143.04, Variance=121.12
# Experiments=5000: Mean=143.20, Variance=118.81
# Experiments=10000: Mean=143.30, Variance=118.40
# Experiments=50000: Mean=143.47, Variance=118.81
# Experiments=100000: Mean=143.49, Variance=119.73
#
# --- 42 Rolls ---
# Experiments=100: Mean=150.00, Variance=135.58
# Experiments=500: Mean=145.87, Variance=117.59
# Experiments=1000: Mean=146.54, Variance=126.16
# Experiments=5000: Mean=146.99, Variance=125.33
# Experiments=10000: Mean=146.76, Variance=123.19
# Experiments=50000: Mean=147.03, Variance=123.16
# Experiments=100000: Mean=147.05, Variance=121.53
#
# --- 43 Rolls ---
# Experiments=100: Mean=149.42, Variance=116.38
# Experiments=500: Mean=150.41, Variance=114.60
# Experiments=1000: Mean=151.06, Variance=118.75
# Experiments=5000: Mean=150.34, Variance=126.94
# Experiments=10000: Mean=150.54, Variance=125.36
# Experiments=50000: Mean=150.42, Variance=125.41
# Experiments=100000: Mean=150.52, Variance=124.96
#
# --- 44 Rolls ---
# Experiments=100: Mean=153.79, Variance=121.95
# Experiments=500: Mean=153.57, Variance=127.06
# Experiments=1000: Mean=154.44, Variance=131.37
# Experiments=5000: Mean=153.80, Variance=126.32
# Experiments=10000: Mean=153.78, Variance=129.11
# Experiments=50000: Mean=154.07, Variance=129.08
# Experiments=100000: Mean=154.00, Variance=128.50
#
# --- 45 Rolls ---
# Experiments=100: Mean=158.60, Variance=131.50
# Experiments=500: Mean=157.73, Variance=126.18
# Experiments=1000: Mean=157.64, Variance=129.08
# Experiments=5000: Mean=157.46, Variance=130.05
# Experiments=10000: Mean=157.47, Variance=130.63
# Experiments=50000: Mean=157.41, Variance=130.94
# Experiments=100000: Mean=157.52, Variance=130.43
#
# --- 46 Rolls ---
# Experiments=100: Mean=161.37, Variance=136.25
# Experiments=500: Mean=161.09, Variance=121.94
# Experiments=1000: Mean=161.09, Variance=135.49
# Experiments=5000: Mean=160.92, Variance=133.61
# Experiments=10000: Mean=160.92, Variance=133.78
# Experiments=50000: Mean=160.93, Variance=134.55
# Experiments=100000: Mean=160.94, Variance=135.10
#
# --- 47 Rolls ---
# Experiments=100: Mean=161.53, Variance=149.19
# Experiments=500: Mean=164.21, Variance=143.80
# Experiments=1000: Mean=164.25, Variance=128.09
# Experiments=5000: Mean=164.37, Variance=136.08
# Experiments=10000: Mean=164.49, Variance=137.78
# Experiments=50000: Mean=164.57, Variance=137.45
# Experiments=100000: Mean=164.47, Variance=135.95
#
# --- 48 Rolls ---
# Experiments=100: Mean=165.83, Variance=146.72
# Experiments=500: Mean=169.02, Variance=154.70
# Experiments=1000: Mean=168.03, Variance=130.98
# Experiments=5000: Mean=167.78, Variance=141.10
# Experiments=10000: Mean=168.01, Variance=140.09
# Experiments=50000: Mean=168.05, Variance=139.44
# Experiments=100000: Mean=167.96, Variance=141.75
#
# --- 49 Rolls ---
# Experiments=100: Mean=170.59, Variance=134.52
# Experiments=500: Mean=171.50, Variance=144.06
# Experiments=1000: Mean=170.63, Variance=137.19
# Experiments=5000: Mean=171.83, Variance=141.53
# Experiments=10000: Mean=171.63, Variance=146.14
# Experiments=50000: Mean=171.48, Variance=141.23
# Experiments=100000: Mean=171.55, Variance=142.64
#
# --- 50 Rolls ---
# Experiments=100: Mean=175.03, Variance=110.29
# Experiments=500: Mean=175.64, Variance=156.33
# Experiments=1000: Mean=174.54, Variance=147.03
# Experiments=5000: Mean=174.74, Variance=148.29
# Experiments=10000: Mean=175.04, Variance=143.24
# Experiments=50000: Mean=174.92, Variance=145.57
# Experiments=100000: Mean=175.02, Variance=145.95
